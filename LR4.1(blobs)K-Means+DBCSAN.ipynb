# %% [markdown]
# # (0) Libs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize']=(12,8)

# %% [markdown]
# # (1) Generate data

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=100, random_state=3, centers=5)

# %% [markdown]
# # (2) Data preparation

# %% [markdown]
# ## (2.1) EDA

# %%
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# ### Optimal number of clusters

# %%
criteries = []
for k in range(2,10):
  KModel=KMeans(n_clusters=k, random_state=3)
  KModel.fit(X)
  criteries.append(KModel.inertia_)

print(criteries)
# Out:
# [1458.2645233765202, 714.6951901800693, 375.3979563127691, 180.3072157858141, 158.05710149704367, 137.15435793146756, 123.38413695230503, 109.54253299375465]

# %%
plt.plot(range(2,10), criteries)

# %% [markdown]
# # (3) Train (K-Means)

# %%
from sklearn.cluster import KMeans
KModel = KMeans(n_clusters=5)
KModel.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = KModel.labels_
print(labels)
# Out:
# [3 1 2 4 1 2 2 1 2 2 4 1 3 1 2 0 0 4 1 1 4 1 4 1 3 2 4 1 4 4 3 0 0 1 2 1 0
#  0 2 3 0 4 2 2 1 3 4 0 0 4 4 1 4 3 0 4 4 0 2 1 3 3 2 3 1 0 3 0 2 3 4 2 4 3
#  3 4 2 0 2 0 0 2 3 0 2 0 3 3 0 4 3 2 1 4 0 1 1 3 1 3]

# %% [markdown]
# # (4) Analysis/Evaluation

# %%
plt.scatter(X[:,0], X[:,1], c=labels, cmap='rainbow')

# %% [markdown]
# # (3) Train (DBSCAN)

# %%
from sklearn.cluster import DBSCAN

clustering = DBSCAN(eps=1.1, min_samples=4).fit_predict(X)
print(clustering)
# Out:
# [ 0  1  2  3  1  2  2  1  2  2  3  1  0 -1  2  4  4  3  1  1  3  1  3  1
#   0  2  3  1 -1  3  0  4  4  1  2  1  4  4 -1  0 -1  3  2  2  1  1  3  4
#   4  3  3  1  3  0  4  3  3  4  2  1  0  0  2  1  1  4 -1  4  2  0  3 -1
#   3  0  0  3  2  4  2  4  4  2  1  4  2  4  0  0 -1  3  1 -1  1  3  4  1
#   1  0  1  1]

# %% [markdown]
# # (4) Analysis/Evaluation

# %%
plt.scatter(X[:,0], X[:,1], c=clustering);
